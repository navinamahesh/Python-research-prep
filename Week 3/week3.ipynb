# %%
import pandas as pd

# %%
from pandas import Series, DataFrame

# %%
pre_survey = pd.read_csv("Data/CSE 11 Fall 2019 DeID/DeID Pre-Survey CSE 11 Fall 2019.csv")

# %%
pa2_data = pd.read_csv("Data/CSE 11 Fall 2019 DeID/DeID Weekly Reflection (CSE 11 PA2).csv")

# %%
print(pre_survey.head(1))
# Out:
#          Timestamp  \
# 0  9/27/2019 16:28
#
#   Did.you.enter.UCSD.as.a.transfer.student.from.another..2.year.or.4.year..college.or.university.  \
# 0                                                 No
#
#   If.your.current.declared.major.is.different.from.your.desired.major..i.e..you.hope.to.switch.majors...what.major.do.you.hope.to.switch.to...Leave.blank.if.this.does.not.apply.to.you..  \
# 0                                                NaN
#
#   What.is.the.main.reason.you.are.taking.this.course.  \
# 0  To fulfill a major requirement (for your curre...
#
#    On.a.scale.of.1.to.5..how.much.experience.did.you.have.with.programming.computer.science.before.you.took.your.FIRST.course.at.UC.San.Diego.  \
# 0                                                3.0
#
#   Please.select.all.of.the.CS.programming.experiences.you.had.before.taking.your.FIRST.CS.course.at.UCSD.  \
# 0  Took AP CS A, Took AP Calculus, Took AP Statis...
#
# ...

# %%
pre_survey = pre_survey.rename(columns =({"Did.you.enter.UCSD.as.a.transfer.student.from.another..2.year.or.4.year..college.or.university.":"transfer_student_status"}))

# %%
pre_survey.head(1)
# Out:
#          Timestamp transfer_student_status  \
# 0  9/27/2019 16:28                      No
#
#   If.your.current.declared.major.is.different.from.your.desired.major..i.e..you.hope.to.switch.majors...what.major.do.you.hope.to.switch.to...Leave.blank.if.this.does.not.apply.to.you..  \
# 0                                                NaN
#
#   What.is.the.main.reason.you.are.taking.this.course.  \
# 0  To fulfill a major requirement (for your curre...
#
#    On.a.scale.of.1.to.5..how.much.experience.did.you.have.with.programming.computer.science.before.you.took.your.FIRST.course.at.UC.San.Diego.  \
# 0                                                3.0
#
#   Please.select.all.of.the.CS.programming.experiences.you.had.before.taking.your.FIRST.CS.course.at.UCSD.  \
# 0  Took AP CS A, Took AP Calculus, Took AP Statis...
#
#   Please.rate.your.current.level.of.experience.with.technology.in.general  \
# 0  A lot of experience: e.g., worked with multipl...
#
# ...

# %%
transferStatusWithDeID = pre_survey[["transfer_student_status","DeID"]]

# %%
print(transferStatusWithDeID)
# Out:
#     transfer_student_status      DeID
# 0                        No  00T90APX
# 1                       Yes  01EAM9F6
# 2                        No  025LQFB2
# 3                        No  039HIM2X
# 4                        No  04T56IGQ
# ..                      ...       ...
# 477                      No  ZWOIJJTE
# 478                      No  ZZ5H6MQD
# 479                      No  ZZCK945I
# 480                     NaN       NaN
# 481                     NaN       NaN
#
# [482 rows x 2 columns]

# %%
transferStatusWithDeID.dropna()
# Out:
#     transfer_student_status      DeID
# 0                        No  00T90APX
# 1                       Yes  01EAM9F6
# 2                        No  025LQFB2
# 3                        No  039HIM2X
# 4                        No  04T56IGQ
# ..                      ...       ...
# 475                      No  ZT9CDKWM
# 476                     Yes  ZTFNAYUD
# 477                      No  ZWOIJJTE
# 478                      No  ZZ5H6MQD
# 479                      No  ZZCK945I
#
# [479 rows x 2 columns]

# %%
onlyTransferStudent = transferStatusWithDeID[transferStatusWithDeID.transfer_student_status == "Yes"]

# %%
print(onlyTransferStudent)
# Out:
#     transfer_student_status      DeID
# 1                       Yes  01EAM9F6
# 21                      Yes  1DSTM3NG
# 24                      Yes  1ORHZ9JA
# 48                      Yes  3D3BRZB7
# 51                      Yes  3LYT1R1X
# 61                      Yes  51MR6YN1
# 76                      Yes  62IJ27VA
# 82                      Yes  6KO63VOW
# 94                      Yes  7GKTBBQY
# 102                     Yes  7S0FMBQB
# 111                     Yes  85YCIZ2K
# 114                     Yes  8FD8NOQY
# 115                     Yes  8G81OREG
# 118                     Yes  8JQRO9KW
# 122                     Yes  8YS6M6C0
# 129                     Yes  9LF9PU4W
# 137                     Yes  AO4WFFN0
# 140                     Yes  ATWZ3PZ6
# 151                     Yes  BC7PMMS4
# 152                     Yes  BCXJAPBJ
# 153                     Yes  BCZGCAJB
# 157                     Yes  BRYF73OQ
# 160                     Yes  BUPICQP4
# 173                     Yes  CLU6PGGE
# ...

# %%
onlyTransferStudent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 1 to 476
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transfer_student_status  60 non-null     object
#  1   DeID                     60 non-null     object
# dtypes: object(2)
# memory usage: 1.4+ KB

# %%
regularStudentsOnly = transferStatusWithDeID[transferStatusWithDeID.transfer_student_status == "No"]

# %%
print(regularStudentsOnly)
# Out:
#     transfer_student_status      DeID
# 0                        No  00T90APX
# 2                        No  025LQFB2
# 3                        No  039HIM2X
# 4                        No  04T56IGQ
# 5                        No  06HH1YB1
# ..                      ...       ...
# 474                      No  ZQRWVMSS
# 475                      No  ZT9CDKWM
# 477                      No  ZWOIJJTE
# 478                      No  ZZ5H6MQD
# 479                      No  ZZCK945I
#
# [419 rows x 2 columns]

# %%
regularStudentsOnly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 419 entries, 0 to 479
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transfer_student_status  419 non-null    object
#  1   DeID                     419 non-null    object
# dtypes: object(2)
# memory usage: 9.8+ KB

# %%
pa2_data.head(1)
# Out:
#         Timestamp  \
# 0  10/9/2019 3:59
#
#    In.the.last.week..approximately.how.many.hours.did.you.spend.outside.of.class.time.working.on.work.for.this.course.  \
# 0                                                7.0
#
#    How.challenging.was.the.work.for.this.class.this.week.  \
# 0                                                  4
#
#   In.the.past.week..which.of.the.following..if.any..did.you.seek.help.from.work.with.for.this.course.  \
# 0                                            A tutor
#
#   In.the.past.week..on.a.scale.of.1.to.5..to.what.degree.did.each.of.the.following.interfere.with.your.ability.to.learn.and.complete.the.work.for.this.course..Requirements.for.other.classes.  \
# 0                                                  3
#
#   In.the.past.week..on.a.scale.of.1.to.5..to.what.degree.did.each.of.the.following.interfere.with.your.ability.to.learn.and.complete.the.work.for.this.course..Illness.  \
# 0                                                  3
#
# ...

# %%
pa2_data = pa2_data.rename(columns = ({"Reflecting.on.the.last.week..how.stressed.have.you.been.overall.":"stress_level"}))

# %%
pa2_data.head(1)
# Out:
#         Timestamp  \
# 0  10/9/2019 3:59
#
#    In.the.last.week..approximately.how.many.hours.did.you.spend.outside.of.class.time.working.on.work.for.this.course.  \
# 0                                                7.0
#
#    How.challenging.was.the.work.for.this.class.this.week.  \
# 0                                                  4
#
#   In.the.past.week..which.of.the.following..if.any..did.you.seek.help.from.work.with.for.this.course.  \
# 0                                            A tutor
#
#   In.the.past.week..on.a.scale.of.1.to.5..to.what.degree.did.each.of.the.following.interfere.with.your.ability.to.learn.and.complete.the.work.for.this.course..Requirements.for.other.classes.  \
# 0                                                  3
#
#   In.the.past.week..on.a.scale.of.1.to.5..to.what.degree.did.each.of.the.following.interfere.with.your.ability.to.learn.and.complete.the.work.for.this.course..Illness.  \
# 0                                                  3
#
# ...

# %%
stressLevel_andDeID = pa2_data[["stress_level","DeID"]] #getting new DataFrame with just 2 important columns

# %%
stressLevel_andDeID.head()
# Out:
#    stress_level      DeID
# 0             3  00T90APX
# 1             2  025LQFB2
# 2             3  039HIM2X
# 3             1  04T56IGQ
# 4             3  0BN8B3XC

# %%
stressLevel_andDeID.dropna()
# Out:
#      stress_level      DeID
# 0               3  00T90APX
# 1               2  025LQFB2
# 2               3  039HIM2X
# 3               1  04T56IGQ
# 4               3  0BN8B3XC
# ..            ...       ...
# 362             3  ZNJX2ETO
# 363             4  ZQRWVMSS
# 364             1  ZT9CDKWM
# 365             2  ZZ5H6MQD
# 366             3  ZZCK945I
#
# [367 rows x 2 columns]

# %%
 finalTable = pd.merge(transferStatusWithDeID,stressLevel_andDeID)

# %%
finalTable.head()
# Out:
#   transfer_student_status      DeID  stress_level
# 0                      No  00T90APX             3
# 1                      No  025LQFB2             2
# 2                      No  039HIM2X             3
# 3                      No  04T56IGQ             1
# 4                      No  0BN8B3XC             3

# %%
finalTable.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 350 entries, 0 to 349
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transfer_student_status  349 non-null    object
#  1   DeID                     350 non-null    object
#  2   stress_level             350 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 10.9+ KB

# %%
pa2_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 28 columns):
#  #   Column                                                                                                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                         --------------  -----
#  0   Timestamp                                                                                                                                                                                                      367 non-null    object
# ...

# %%
numberOfTransferStudents = finalTable[finalTable.transfer_student_status == "Yes"]

# %%
numberOfTransferStudents.head()
# Out:
#    transfer_student_status      DeID  stress_level
# 14                     Yes  1DSTM3NG             2
# 34                     Yes  3D3BRZB7             1
# 37                     Yes  3LYT1R1X             4
# 47                     Yes  51MR6YN1             4
# 57                     Yes  62IJ27VA             3

# %%
numberOfTransferStudents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34 entries, 14 to 344
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transfer_student_status  34 non-null     object
#  1   DeID                     34 non-null     object
#  2   stress_level             34 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.1+ KB

# %%
onlyRegularStudents = finalTable[finalTable.transfer_student_status == "No"]

# %%
onlyRegularStudents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 315 entries, 0 to 349
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transfer_student_status  315 non-null    object
#  1   DeID                     315 non-null    object
#  2   stress_level             315 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 9.8+ KB

# %%
len(finalTable)
# Out:
# 350

# %%
len(numberOfTransferStudents)
# Out:
# 34

# %%
len(onlyRegularStudents)
# Out:
# 315

# %%
finalTable.dropna
# Out:
# <bound method DataFrame.dropna of     transfer_student_status      DeID  stress_level
# 0                        No  00T90APX             3
# 1                        No  025LQFB2             2
# 2                        No  039HIM2X             3
# 3                        No  04T56IGQ             1
# 4                        No  0BN8B3XC             3
# ..                      ...       ...           ...
# 345                      No  ZNJX2ETO             3
# 346                      No  ZQRWVMSS             4
# 347                      No  ZT9CDKWM             1
# 348                      No  ZZ5H6MQD             2
# 349                      No  ZZCK945I             3
#
# [350 rows x 3 columns]>

# %%
finalTable.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 350 entries, 0 to 349
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transfer_student_status  349 non-null    object
#  1   DeID                     350 non-null    object
#  2   stress_level             350 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 10.9+ KB

# %%
finalTable.head()
# Out:
#   transfer_student_status      DeID  stress_level
# 0                      No  00T90APX             3
# 1                      No  025LQFB2             2
# 2                      No  039HIM2X             3
# 3                      No  04T56IGQ             1
# 4                      No  0BN8B3XC             3

# %%
finalTable.head(10)
# Out:
#   transfer_student_status      DeID  stress_level
# 0                      No  00T90APX             3
# 1                      No  025LQFB2             2
# 2                      No  039HIM2X             3
# 3                      No  04T56IGQ             1
# 4                      No  0BN8B3XC             3
# 5                      No  0HTK8PFK             3
# 6                      No  0R0SO5DC             2
# 7                      No  0SE59GTA             2
# 8                      No  0SM3FBZU             2
# 9                      No  0W57L40H             3

# %%
finalTable.head(15)
# Out:
#    transfer_student_status      DeID  stress_level
# 0                       No  00T90APX             3
# 1                       No  025LQFB2             2
# 2                       No  039HIM2X             3
# 3                       No  04T56IGQ             1
# 4                       No  0BN8B3XC             3
# 5                       No  0HTK8PFK             3
# 6                       No  0R0SO5DC             2
# 7                       No  0SE59GTA             2
# 8                       No  0SM3FBZU             2
# 9                       No  0W57L40H             3
# 10                      No  0WM0GY4D             1
# 11                      No  0X8PYQ4D             3
# 12                      No  0ZOW1CTF             2
# 13                      No  160WYO75             2
# 14                     Yes  1DSTM3NG             2

# %%
finalTable.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 350 entries, 0 to 349
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transfer_student_status  349 non-null    object
#  1   DeID                     350 non-null    object
#  2   stress_level             350 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 10.9+ KB

# %%
numberOfTransferStudents.head()
# Out:
#    transfer_student_status      DeID  stress_level
# 14                     Yes  1DSTM3NG             2
# 34                     Yes  3D3BRZB7             1
# 37                     Yes  3LYT1R1X             4
# 47                     Yes  51MR6YN1             4
# 57                     Yes  62IJ27VA             3

# %%
transferStressMean = numberOfTransferStudents["stress_level"].mean()

# %%
print(transferStressMean)
# Out:
# 2.911764705882353

# %%
regularStudents_stressAverage = onlyRegularStudents["stress_level"].mean()

# %%
print(onlyRegularStudents)
# Out:
#     transfer_student_status      DeID  stress_level
# 0                        No  00T90APX             3
# 1                        No  025LQFB2             2
# 2                        No  039HIM2X             3
# 3                        No  04T56IGQ             1
# 4                        No  0BN8B3XC             3
# ..                      ...       ...           ...
# 345                      No  ZNJX2ETO             3
# 346                      No  ZQRWVMSS             4
# 347                      No  ZT9CDKWM             1
# 348                      No  ZZ5H6MQD             2
# 349                      No  ZZCK945I             3
#
# [315 rows x 3 columns]

# %%
print(regularStudents_stressAverage)
# Out:
# 2.6825396825396823

# %%
pa2_data = pa2_data.rename(columns =({"How.challenging.was.the.work.for.this.class.this.week.": "challenging"}))

# %%
pa2_data.head()
# Out:
#           Timestamp  \
# 0    10/9/2019 3:59
# 1   10/8/2019 17:24
# 2  10/10/2019 17:25
# 3   10/2/2019 21:11
# 4   10/8/2019 21:11
#
#    In.the.last.week..approximately.how.many.hours.did.you.spend.outside.of.class.time.working.on.work.for.this.course.  \
# 0                                                7.0
# 1                                                7.0
# 2                                                1.0
# 3                                                5.0
# 4                                                8.0
#
#    challenging  \
# 0            4
# 1            3
# 2            1
# 3            2
# 4            3
#
#   In.the.past.week..which.of.the.following..if.any..did.you.seek.help.from.work.with.for.this.course.  \
# 0                                            A tutor
# 1  My peer(s) in this class (as pair programming/...
# 2  I did not seek help or work with anyone this week
# 3                                     The instructor
# ...

# %%
challenging_and_DeID = pa2_data[["challenging","DeID"]] #only keeping two columns

# %%
challenging_and_DeID.head()
# Out:
#    challenging      DeID
# 0            4  00T90APX
# 1            3  025LQFB2
# 2            1  039HIM2X
# 3            2  04T56IGQ
# 4            3  0BN8B3XC

# %%
extensionTable = pd.merge(transferStatusWithDeID,challenging_and_DeID)

# %%
extensionTable.head() #viewing table with transfer student status, DeID and challenging score
# Out:
#   transfer_student_status      DeID  challenging
# 0                      No  00T90APX            4
# 1                      No  025LQFB2            3
# 2                      No  039HIM2X            1
# 3                      No  04T56IGQ            2
# 4                      No  0BN8B3XC            3

# %%
transferStudentsOnly = extensionTable[extensionTable.transfer_student_status == "Yes"]

# %%
transferStudentsOnly.head() #only transfer students and how challenging they found the work for the week
# Out:
#    transfer_student_status      DeID  challenging
# 14                     Yes  1DSTM3NG            3
# 34                     Yes  3D3BRZB7            1
# 37                     Yes  3LYT1R1X            5
# 47                     Yes  51MR6YN1            3
# 57                     Yes  62IJ27VA            3

# %%
transferStudentsExperience_average = transferStudentsOnly["challenging"].mean()

# %%
print(transferStudentsExperience_average)
# Out:
# 3.1470588235294117

# %%
regularStudentsOnly = extensionTable[extensionTable.transfer_student_status == "No"]

# %%
regularStudentsOnly.head()
# Out:
#   transfer_student_status      DeID  challenging
# 0                      No  00T90APX            4
# 1                      No  025LQFB2            3
# 2                      No  039HIM2X            1
# 3                      No  04T56IGQ            2
# 4                      No  0BN8B3XC            3

# %%
regularStudentsChallenging_average = regularStudentsOnly["challenging"].mean()

# %%
print(regularStudentsChallenging_average)
# Out:
# 3.184126984126984
